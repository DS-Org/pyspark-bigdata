# %% [markdown]
# # Linear regression using spark ML

# %%
from pyspark.sql import SparkSession

# %%
from pyspark.ml.regression import LinearRegression

# %%
# vector is a data structure used by linear regression in spark ML
from pyspark.ml.linalg import Vectors

spark = SparkSession.builder.appName("linear regression").getOrCreate()

# %% [markdown]
# Lets read the rdd from text file

# %%
dataset = spark.sparkContext.textFile("./datasets/regression.txt")

# %%
regression_data = dataset.map(lambda x : x.split(",")).map(lambda field: (float(field[0]) , Vectors.dense(float(field[1])) ))

# %%
#use createDataFrame only when using spark sql commands

regression_df = regression_data.toDF(['label','features'])
regression_df.sample(False,0.01).show()
# Out:
# +-----+--------+
# |label|features|
# +-----+--------+
# |-0.84|  [0.83]|
# | 0.43| [-0.47]|
# | 0.34|  [-0.4]|
# | -0.6|  [0.56]|
# |-0.78|  [0.95]|
# |-1.34|  [1.33]|
# | 0.44| [-0.38]|
# | -0.6|  [0.35]|
# | 0.91| [-0.95]|
# |-1.36|  [1.37]|
# |-1.39|  [1.44]|
# | 0.87| [-1.02]|
# | 0.51| [-0.38]|
# +-----+--------+

# %% [markdown]
# ### SPlit the data into training and testing data

# %%
trainTest = regression_df.randomSplit([0.5,0.5])
len(trainTest)
# Out:
# 2

# %%
train_data= trainTest[0]
test_data = trainTest[1]

# %%
lir = LinearRegression(maxIter=10,regParam=0.3, elasticNetParam=0.8)

# %%
model = lir.fit(train_data)

# %%
full_predictions = model.transform(test_data).cache()

# %%
#sample
full_predictions.sample(False,0.001,20).collect()
# Out:
# [Row(label=-0.18, features=DenseVector([0.1]), prediction=-0.07016462343013741)]

# %%
prediction = full_predictions.select('prediction').rdd.map(lambda x: x[0])
labels= full_predictions.select('label').rdd.map(lambda x: x[0])

# %%
results = prediction.zip(labels)

# %%
for result in results.collect():
    print("prediction %.10f , for label - %.2f" % result)
# Out:
# prediction -2.7120197082 , for label - -3.74
# prediction -1.7276572656 , for label - -2.54
# prediction -1.6263258377 , for label - -2.26
# prediction -1.4236629819 , for label - -2.09
# prediction -1.4743286959 , for label - -2.07
# prediction -1.4309009410 , for label - -1.96
# prediction -1.4019491045 , for label - -1.94
# prediction -1.4309009410 , for label - -1.94
# prediction -1.3440454314 , for label - -1.91
# prediction -1.4309009410 , for label - -1.87
# prediction -1.1992862487 , for label - -1.77
# prediction -1.2210001261 , for label - -1.75
# prediction -1.1992862487 , for label - -1.74
# prediction -1.1848103304 , for label - -1.66
# prediction -1.1775723713 , for label - -1.65
# prediction -1.3295695131 , for label - -1.64
# prediction -1.1775723713 , for label - -1.60
# prediction -1.1703344121 , for label - -1.59
# prediction -1.1486205347 , for label - -1.42
# prediction -0.9531956381 , for label - -1.40
# prediction -0.9531956381 , for label - -1.39
# prediction -0.9025299241 , for label - -1.37
# prediction -1.0183372703 , for label - -1.36
# prediction -1.0690029842 , for label - -1.33
# prediction -0.8518642101 , for label - -1.30
# prediction -0.8229123736 , for label - -1.29
# prediction -0.8663401284 , for label - -1.25
# prediction -0.9531956381 , for label - -1.25
# prediction -0.8591021693 , for label - -1.23
# prediction -0.8663401284 , for label - -1.22
# prediction -0.8011984962 , for label - -1.20
# prediction -0.7939605371 , for label - -1.12
# prediction -0.7794846188 , for label - -1.10
# prediction -0.7650087005 , for label - -1.09
# prediction -0.8084364553 , for label - -1.08
# prediction -0.7722466596 , for label - -1.03
# prediction -0.6636772726 , for label - -1.01
# prediction -0.6564393135 , for label - -0.97
# prediction -0.7650087005 , for label - -0.96
# prediction -0.7215809457 , for label - -0.94
# prediction -0.7360568640 , for label - -0.94
# prediction -0.6564393135 , for label - -0.91
# prediction -0.6347254361 , for label - -0.89
# prediction -0.7505327822 , for label - -0.89
# prediction -0.5551078856 , for label - -0.88
# prediction -0.6274874769 , for label - -0.87
# prediction -0.5768217630 , for label - -0.85
# prediction -0.6419633952 , for label - -0.84
# prediction -0.5044421716 , for label - -0.82
# prediction -0.6419633952 , for label - -0.81
# prediction -0.5768217630 , for label - -0.80
# prediction -0.5840597221 , for label - -0.78
# prediction -0.4754903351 , for label - -0.76
# prediction -0.6057735995 , for label - -0.76
# prediction -0.5189180899 , for label - -0.75
# prediction -0.3958727846 , for label - -0.71
# prediction -0.6347254361 , for label - -0.71
# prediction -0.5333940081 , for label - -0.69
# prediction -0.6347254361 , for label - -0.68
# prediction -0.4827282942 , for label - -0.67
# prediction -0.4682523759 , for label - -0.66
# prediction -0.4103487028 , for label - -0.65
# prediction -0.6347254361 , for label - -0.65
# prediction -0.4393005394 , for label - -0.63
# prediction -0.4175866620 , for label - -0.62
# prediction -0.4393005394 , for label - -0.60
# prediction -0.4754903351 , for label - -0.59
# prediction -0.3886348254 , for label - -0.57
# prediction -0.2221617653 , for label - -0.53
# prediction -0.4465384985 , for label - -0.53
# prediction -0.2438756427 , for label - -0.51
# prediction -0.3090172749 , for label - -0.51
# prediction -0.4031107437 , for label - -0.50
# prediction -0.3162552341 , for label - -0.49
# prediction -0.3958727846 , for label - -0.48
# prediction -0.4610144168 , for label - -0.46
# prediction -0.2293997244 , for label - -0.45
# prediction -0.3234931932 , for label - -0.42
# prediction -0.3669209480 , for label - -0.41
# prediction -0.2945413567 , for label - -0.36
# prediction -0.1859719696 , for label - -0.35
# prediction -0.1787340105 , for label - -0.34
# prediction -0.2076858470 , for label - -0.33
# prediction -0.2800654384 , for label - -0.33
# prediction -0.1497821739 , for label - -0.32
# prediction -0.2511136018 , for label - -0.30
# prediction -0.3017793158 , for label - -0.30
# prediction -0.1135923782 , for label - -0.27
# prediction -0.2004478879 , for label - -0.25
# prediction -0.1859719696 , for label - -0.24
# prediction -0.1932099287 , for label - -0.24
# prediction -0.2076858470 , for label - -0.24
# prediction -0.1714960513 , for label - -0.23
# prediction -0.2076858470 , for label - -0.23
# prediction -0.2076858470 , for label - -0.22
# prediction -0.2076858470 , for label - -0.19
# prediction -0.1353062557 , for label - -0.17
# prediction -0.1135923782 , for label - -0.16
# prediction -0.1570201331 , for label - -0.16
# prediction -0.0122609503 , for label - -0.14
# prediction -0.0918785008 , for label - -0.14
# prediction -0.0484507460 , for label - -0.10
# prediction -0.0774025826 , for label - -0.10
# prediction -0.0701646234 , for label - -0.09
# prediction -0.1208303374 , for label - -0.09
# prediction -0.0991164600 , for label - -0.08
# prediction -0.0412127869 , for label - -0.07
# prediction -0.1570201331 , for label - -0.07
# prediction 0.0166908862 , for label - -0.05
# prediction -0.0412127869 , for label - -0.05
# prediction -0.0412127869 , for label - -0.05
# prediction -0.1280682965 , for label - -0.05
# prediction 0.0963084367 , for label - -0.04
# prediction -0.0050229912 , for label - -0.04
# prediction 0.0601186410 , for label - -0.02
# prediction 0.0311668045 , for label - -0.02
# prediction 0.0311668045 , for label - -0.02
# prediction 0.0311668045 , for label - -0.01
# prediction -0.1497821739 , for label - -0.01
# prediction -0.0194989095 , for label - -0.00
# prediction 0.0528806819 , for label - 0.00
# prediction 0.0456427227 , for label - 0.01
# prediction 0.0384047636 , for label - 0.02
# prediction -0.0050229912 , for label - 0.04
# prediction 0.0528806819 , for label - 0.05
# prediction 0.0166908862 , for label - 0.05
# prediction 0.0456427227 , for label - 0.08
# prediction -0.0267368686 , for label - 0.08
# prediction 0.1180223141 , for label - 0.09
# prediction 0.0311668045 , for label - 0.09
# prediction 0.0166908862 , for label - 0.09
# prediction -0.0050229912 , for label - 0.09
# prediction 0.1324982324 , for label - 0.10
# prediction 0.0673566002 , for label - 0.11
# prediction -0.0339748277 , for label - 0.11
# prediction 0.1035463958 , for label - 0.14
# prediction 0.0818325184 , for label - 0.14
# prediction 0.1469741507 , for label - 0.15
# prediction 0.1542121098 , for label - 0.16
# prediction 0.0456427227 , for label - 0.16
# prediction 0.2772574151 , for label - 0.17
# prediction 0.0673566002 , for label - 0.17
# prediction 0.1324982324 , for label - 0.18
# prediction 0.1904019055 , for label - 0.20
# prediction 0.1686880281 , for label - 0.21
# prediction 0.1686880281 , for label - 0.21
# prediction 0.2265917012 , for label - 0.22
# prediction 0.2265917012 , for label - 0.23
# prediction 0.1759259872 , for label - 0.23
# prediction 0.1324982324 , for label - 0.25
# prediction 0.2483055786 , for label - 0.26
# prediction 0.1469741507 , for label - 0.26
# prediction 0.2555435377 , for label - 0.28
# prediction 0.2917333334 , for label - 0.29
# prediction 0.1831639463 , for label - 0.29
# prediction 0.1180223141 , for label - 0.29
# prediction 0.3279231291 , for label - 0.30
# prediction 0.2627814968 , for label - 0.30
# prediction 0.2121157829 , for label - 0.30
# prediction 0.2193537420 , for label - 0.31
# prediction 0.2193537420 , for label - 0.32
# prediction 0.1831639463 , for label - 0.33
# prediction 0.2917333334 , for label - 0.34
# prediction 0.2627814968 , for label - 0.34
# prediction 0.2483055786 , for label - 0.35
# prediction 0.3423990473 , for label - 0.36
# prediction 0.3062092517 , for label - 0.39
# prediction 0.3279231291 , for label - 0.40
# prediction 0.2627814968 , for label - 0.40
# prediction 0.2989712925 , for label - 0.41
# prediction 0.2844953742 , for label - 0.41
# prediction 0.3134472108 , for label - 0.42
# prediction 0.2989712925 , for label - 0.42
# prediction 0.3062092517 , for label - 0.43
# prediction 0.3062092517 , for label - 0.43
# prediction 0.2989712925 , for label - 0.45
# prediction 0.3206851699 , for label - 0.46
# prediction 0.3134472108 , for label - 0.46
# prediction 0.3206851699 , for label - 0.49
# prediction 0.2700194560 , for label - 0.49
# prediction 0.3496370065 , for label - 0.50
# prediction 0.4509684344 , for label - 0.51
# prediction 0.4943961892 , for label - 0.55
# prediction 0.4437304752 , for label - 0.58
# prediction 0.4147786387 , for label - 0.58
# prediction 0.5088721075 , for label - 0.64
# prediction 0.4509684344 , for label - 0.64
# prediction 0.3279231291 , for label - 0.65
# prediction 0.5161100666 , for label - 0.66
# prediction 0.4654443527 , for label - 0.68
# prediction 0.5305859849 , for label - 0.69
# prediction 0.6463933311 , for label - 0.70
# prediction 0.4003027204 , for label - 0.70
# prediction 0.3858268022 , for label - 0.70
# prediction 0.5595378214 , for label - 0.71
# prediction 0.5884896580 , for label - 0.72
# prediction 0.5884896580 , for label - 0.72
# prediction 0.4654443527 , for label - 0.74
# prediction 0.4220165978 , for label - 0.74
# prediction 0.6681072085 , for label - 0.75
# prediction 0.5595378214 , for label - 0.76
# prediction 0.5233480257 , for label - 0.79
# prediction 0.5233480257 , for label - 0.81
# prediction 0.6970590450 , for label - 0.82
# prediction 0.6029655762 , for label - 0.82
# prediction 0.5957276171 , for label - 0.84
# prediction 0.5595378214 , for label - 0.85
# prediction 0.4582063935 , for label - 0.89
# prediction 0.6319174128 , for label - 0.90
# prediction 0.6174414945 , for label - 0.93
# prediction 0.5740137397 , for label - 0.93
# prediction 0.7332488407 , for label - 0.95
# prediction 0.7839145546 , for label - 0.96
# prediction 0.7115349633 , for label - 0.97
# prediction 0.6463933311 , for label - 0.97
# prediction 0.6174414945 , for label - 0.97
# prediction 0.6608692493 , for label - 0.98
# prediction 0.6608692493 , for label - 0.98
# prediction 0.7042970041 , for label - 1.00
# prediction 0.7042970041 , for label - 1.01
# prediction 0.8345802686 , for label - 1.05
# prediction 0.5812516988 , for label - 1.05
# prediction 0.7622006772 , for label - 1.06
# prediction 0.7694386364 , for label - 1.07
# prediction 0.7839145546 , for label - 1.08
# prediction 0.7187729224 , for label - 1.10
# prediction 0.9359116965 , for label - 1.11
# prediction 0.8707700643 , for label - 1.11
# prediction 0.8418182277 , for label - 1.11
# prediction 0.8780080234 , for label - 1.14
# prediction 0.8852459826 , for label - 1.16
# prediction 0.8345802686 , for label - 1.20
# prediction 0.8562941460 , for label - 1.24
# prediction 0.9214357782 , for label - 1.28
# prediction 1.0734329201 , for label - 1.39
# prediction 0.9503876148 , for label - 1.42
# prediction 1.0806708792 , for label - 1.48
# prediction 1.0517190427 , for label - 1.49
# prediction 1.1675263889 , for label - 1.50
# prediction 1.1602884297 , for label - 1.50
# prediction 1.1675263889 , for label - 1.51
# prediction 1.0951467975 , for label - 1.52
# prediction 1.0806708792 , for label - 1.54
# prediction 0.8924839417 , for label - 1.55
# prediction 1.3050476125 , for label - 1.62
# prediction 1.0879088384 , for label - 1.63
# prediction 1.3701892447 , for label - 1.72
# prediction 1.2978096533 , for label - 1.80
# prediction 1.3050476125 , for label - 1.90
# prediction 1.5149484274 , for label - 1.93
# prediction 1.4136169995 , for label - 1.96
# prediction 1.5511382231 , for label - 2.09
# prediction 1.5873280188 , for label - 2.14
# prediction 1.5583761822 , for label - 2.33
# prediction 1.8334186294 , for label - 2.48
# prediction 1.8840843434 , for label - 2.56
# prediction -1.7638470613 , for label - -2.45
# prediction -1.5105184915 , for label - -2.14
# prediction -1.3368074723 , for label - -1.97
# prediction -1.4091870636 , for label - -1.91
# prediction -1.3729972680 , for label - -1.84
# prediction -1.2137621670 , for label - -1.83
# prediction -1.3368074723 , for label - -1.82
# prediction -1.3006176766 , for label - -1.80
# prediction -1.2354760444 , for label - -1.68
# prediction -1.2644278809 , for label - -1.68
# prediction -1.1630964530 , for label - -1.66
# prediction -1.1124307390 , for label - -1.60
# prediction -1.1486205347 , for label - -1.59
# prediction -1.0762409434 , for label - -1.54
# prediction -1.0110993111 , for label - -1.50
# prediction -1.0979548208 , for label - -1.45
# prediction -0.9966233929 , for label - -1.43
# prediction -0.9387197198 , for label - -1.40
# prediction -1.0545270660 , for label - -1.40
# prediction -0.8880540058 , for label - -1.38
# prediction -0.9893854337 , for label - -1.36
# prediction -0.8952919650 , for label - -1.35
# prediction -0.9604335972 , for label - -1.34
# prediction -0.8011984962 , for label - -1.30
# prediction -0.9893854337 , for label - -1.30
# prediction -0.8446262510 , for label - -1.24
# prediction -0.9459576789 , for label - -1.20
# prediction -0.9821474746 , for label - -1.20
# prediction -0.8084364553 , for label - -1.17
# prediction -0.9314817606 , for label - -1.15
# prediction -0.6564393135 , for label - -1.14
# prediction -0.7722466596 , for label - -1.10
# prediction -0.7505327822 , for label - -1.09
# prediction -0.8518642101 , for label - -1.08
# prediction -0.6347254361 , for label - -1.03
# prediction -0.6926291091 , for label - -1.02
# prediction -0.7215809457 , for label - -1.00
# prediction -0.7794846188 , for label - -0.99
# prediction -0.8518642101 , for label - -0.98
# prediction -0.5695838038 , for label - -0.97
# prediction -0.7505327822 , for label - -0.97
# prediction -0.6419633952 , for label - -0.96
# prediction -0.7071050274 , for label - -0.96
# prediction -0.5768217630 , for label - -0.93
# prediction -0.6564393135 , for label - -0.93
# prediction -0.7215809457 , for label - -0.92
# prediction -0.7360568640 , for label - -0.92
# prediction -0.5116801307 , for label - -0.91
# prediction -0.6202495178 , for label - -0.91
# prediction -0.5623458447 , for label - -0.90
# prediction -0.6564393135 , for label - -0.89
# prediction -0.5840597221 , for label - -0.88
# prediction -0.5985356404 , for label - -0.85
# prediction -0.6130115586 , for label - -0.85
# prediction -0.5985356404 , for label - -0.81
# prediction -0.5768217630 , for label - -0.80
# prediction -0.6564393135 , for label - -0.79
# prediction -0.6853911500 , for label - -0.79
# prediction -0.6781531909 , for label - -0.78
# prediction -0.6853911500 , for label - -0.78
# prediction -0.6781531909 , for label - -0.77
# prediction -0.6057735995 , for label - -0.75
# prediction -0.4537764577 , for label - -0.73
# prediction -0.4827282942 , for label - -0.73
# prediction -0.5333940081 , for label - -0.73
# prediction -0.4248246211 , for label - -0.72
# prediction -0.4827282942 , for label - -0.72
# prediction -0.4465384985 , for label - -0.71
# prediction -0.4899662533 , for label - -0.71
# prediction -0.4103487028 , for label - -0.69
# prediction -0.4465384985 , for label - -0.64
# prediction -0.3524450297 , for label - -0.63
# prediction -0.3958727846 , for label - -0.63
# prediction -0.4537764577 , for label - -0.61
# prediction -0.5333940081 , for label - -0.61
# prediction -0.3813968663 , for label - -0.60
# prediction -0.3886348254 , for label - -0.59
# prediction -0.4320625802 , for label - -0.59
# prediction -0.3017793158 , for label - -0.57
# prediction -0.2945413567 , for label - -0.56
# prediction -0.4610144168 , for label - -0.56
# prediction -0.2873033975 , for label - -0.54
# prediction -0.4031107437 , for label - -0.52
# prediction -0.2438756427 , for label - -0.48
# prediction -0.4103487028 , for label - -0.48
# prediction -0.4972042125 , for label - -0.48
# prediction -0.3379691115 , for label - -0.47
# prediction -0.3090172749 , for label - -0.44
# prediction -0.3234931932 , for label - -0.44
# prediction -0.3596829889 , for label - -0.44
# prediction -0.2583515610 , for label - -0.42
# prediction -0.2945413567 , for label - -0.41
# prediction -0.1570201331 , for label - -0.40
# prediction -0.2149238062 , for label - -0.40
# prediction -0.2655895201 , for label - -0.40
# prediction -0.3307311523 , for label - -0.40
# prediction -0.1570201331 , for label - -0.39
# prediction -0.3234931932 , for label - -0.39
# prediction -0.1208303374 , for label - -0.38
# prediction -0.3162552341 , for label - -0.37
# prediction -0.3452070706 , for label - -0.36
# prediction -0.3017793158 , for label - -0.35
# prediction -0.2293997244 , for label - -0.34
# prediction -0.1787340105 , for label - -0.33
# prediction -0.1787340105 , for label - -0.32
# prediction -0.2583515610 , for label - -0.32
# prediction -0.1859719696 , for label - -0.31
# prediction -0.1135923782 , for label - -0.30
# prediction -0.1135923782 , for label - -0.30
# prediction -0.1280682965 , for label - -0.30
# prediction -0.2873033975 , for label - -0.30
# prediction -0.2945413567 , for label - -0.29
# prediction -0.1932099287 , for label - -0.28
# prediction -0.2366376836 , for label - -0.28
# prediction -0.1859719696 , for label - -0.25
# prediction -0.2800654384 , for label - -0.25
# prediction -0.0991164600 , for label - -0.21
# prediction -0.2366376836 , for label - -0.21
# prediction -0.1135923782 , for label - -0.19
# prediction -0.1135923782 , for label - -0.19
# prediction -0.1497821739 , for label - -0.19
# prediction -0.0701646234 , for label - -0.18
# prediction -0.2221617653 , for label - -0.18
# prediction -0.0484507460 , for label - -0.17
# prediction -0.1280682965 , for label - -0.15
# prediction -0.2076858470 , for label - -0.14
# prediction -0.0267368686 , for label - -0.13
# prediction -0.1135923782 , for label - -0.13
# prediction 0.0239288453 , for label - -0.12
# prediction -0.1932099287 , for label - -0.12
# prediction -0.1063544191 , for label - -0.11
# prediction -0.0122609503 , for label - -0.10
# prediction -0.0701646234 , for label - -0.10
# prediction -0.0484507460 , for label - -0.07
# prediction -0.0050229912 , for label - -0.05
# prediction -0.0122609503 , for label - -0.05
# prediction -0.1642580922 , for label - -0.04
# prediction 0.0890704776 , for label - -0.02
# prediction 0.0818325184 , for label - -0.02
# prediction -0.0991164600 , for label - -0.02
# prediction -0.0629266643 , for label - -0.01
# prediction 0.0745945593 , for label - -0.00
# prediction 0.0745945593 , for label - 0.03
# prediction 0.0456427227 , for label - 0.05
# prediction 0.0022149679 , for label - 0.05
# prediction 0.1324982324 , for label - 0.06
# prediction 0.1035463958 , for label - 0.06
# prediction 0.0601186410 , for label - 0.08
# prediction 0.1614500689 , for label - 0.10
# prediction 0.0528806819 , for label - 0.10
# prediction 0.0311668045 , for label - 0.11
# prediction 0.0094529271 , for label - 0.11
# prediction -0.0050229912 , for label - 0.12
# prediction 0.1107843550 , for label - 0.13
# prediction 0.2265917012 , for label - 0.14
# prediction 0.0601186410 , for label - 0.14
# prediction 0.1976398646 , for label - 0.15
# prediction 0.2265917012 , for label - 0.16
# prediction 0.2844953742 , for label - 0.18
# prediction 0.1542121098 , for label - 0.18
# prediction 0.0528806819 , for label - 0.18
# prediction 0.2338296603 , for label - 0.22
# prediction 0.2193537420 , for label - 0.24
# prediction 0.2048778237 , for label - 0.24
# prediction 0.2265917012 , for label - 0.26
# prediction 0.2121157829 , for label - 0.26
# prediction 0.1976398646 , for label - 0.29
# prediction 0.1686880281 , for label - 0.29
# prediction 0.1542121098 , for label - 0.30
# prediction 0.2265917012 , for label - 0.31
# prediction 0.2772574151 , for label - 0.32
# prediction 0.1252602732 , for label - 0.33
# prediction 0.3785888430 , for label - 0.34
# prediction 0.3641129247 , for label - 0.35
# prediction 0.3134472108 , for label - 0.36
# prediction 0.3423990473 , for label - 0.37
# prediction 0.3785888430 , for label - 0.38
# prediction 0.2410676194 , for label - 0.38
# prediction 0.1904019055 , for label - 0.38
# prediction 0.3713508839 , for label - 0.40
# prediction 0.3206851699 , for label - 0.41
# prediction 0.2772574151 , for label - 0.44
# prediction 0.4726823118 , for label - 0.45
# prediction 0.4582063935 , for label - 0.45
# prediction 0.3423990473 , for label - 0.45
# prediction 0.4726823118 , for label - 0.50
# prediction 0.2772574151 , for label - 0.51
# prediction 0.3206851699 , for label - 0.53
# prediction 0.4799202709 , for label - 0.55
# prediction 0.2410676194 , for label - 0.55
# prediction 0.2844953742 , for label - 0.56
# prediction 0.5450619031 , for label - 0.61
# prediction 0.4075406796 , for label - 0.61
# prediction 0.5088721075 , for label - 0.63
# prediction 0.4726823118 , for label - 0.63
# prediction 0.4654443527 , for label - 0.65
# prediction 0.4364925161 , for label - 0.65
# prediction 0.4654443527 , for label - 0.67
# prediction 0.6102035354 , for label - 0.68
# prediction 0.5305859849 , for label - 0.69
# prediction 0.5667757806 , for label - 0.72
# prediction 0.5812516988 , for label - 0.73
# prediction 0.5088721075 , for label - 0.73
# prediction 0.5667757806 , for label - 0.74
# prediction 0.6174414945 , for label - 0.75
# prediction 0.5378239440 , for label - 0.77
# prediction 0.5667757806 , for label - 0.78
# prediction 0.5016341483 , for label - 0.78
# prediction 0.5884896580 , for label - 0.81
# prediction 0.5305859849 , for label - 0.82
# prediction 0.4292545570 , for label - 0.84
# prediction 0.6970590450 , for label - 0.86
# prediction 0.7404867998 , for label - 0.87
# prediction 0.5812516988 , for label - 0.88
# prediction 0.6029655762 , for label - 0.89
# prediction 0.6970590450 , for label - 0.90
# prediction 0.6536312902 , for label - 0.90
# prediction 0.6898210859 , for label - 0.91
# prediction 0.6970590450 , for label - 0.93
# prediction 0.6753451676 , for label - 0.93
# prediction 0.7622006772 , for label - 0.95
# prediction 0.6898210859 , for label - 0.95
# prediction 0.6463933311 , for label - 0.95
# prediction 0.6246794536 , for label - 0.95
# prediction 0.7622006772 , for label - 0.96
# prediction 0.6102035354 , for label - 0.97
# prediction 0.8345802686 , for label - 0.98
# prediction 0.7694386364 , for label - 0.98
# prediction 0.7187729224 , for label - 0.98
# prediction 0.7260108816 , for label - 0.99
# prediction 0.7839145546 , for label - 1.00
# prediction 0.7549627181 , for label - 1.00
# prediction 0.6825831267 , for label - 1.01
# prediction 0.6536312902 , for label - 1.01
# prediction 0.7839145546 , for label - 1.05
# prediction 0.8056284321 , for label - 1.08
# prediction 0.8056284321 , for label - 1.09
# prediction 0.7622006772 , for label - 1.09
# prediction 0.9721014922 , for label - 1.13
# prediction 0.7839145546 , for label - 1.13
# prediction 0.8345802686 , for label - 1.16
# prediction 0.7622006772 , for label - 1.16
# prediction 1.0155292470 , for label - 1.17
# prediction 0.8780080234 , for label - 1.17
# prediction 0.8635321051 , for label - 1.19
# prediction 0.8707700643 , for label - 1.20
# prediction 0.9648635331 , for label - 1.25
# prediction 0.9503876148 , for label - 1.26
# prediction 0.8707700643 , for label - 1.27
# prediction 0.8707700643 , for label - 1.28
# prediction 1.0372431244 , for label - 1.29
# prediction 0.9503876148 , for label - 1.34
# prediction 0.9214357782 , for label - 1.44
# prediction 1.0879088384 , for label - 1.45
# prediction 1.1313365932 , for label - 1.50
# prediction 1.1023847566 , for label - 1.52
# prediction 1.1602884297 , for label - 1.55
# prediction 1.1458125115 , for label - 1.59
# prediction 1.1313365932 , for label - 1.74
# prediction 1.1023847566 , for label - 1.74
# prediction 1.2543818985 , for label - 1.76
# prediction 1.2254300620 , for label - 1.80
# prediction 1.3339994490 , for label - 1.82
# prediction 1.3557133264 , for label - 1.86
# prediction 1.2399059802 , for label - 1.93
# prediction 1.5221863865 , for label - 1.95
# prediction 1.5077104683 , for label - 2.09
# prediction 1.6814214875 , for label - 2.27
# prediction 1.9492259756 , for label - 2.62
